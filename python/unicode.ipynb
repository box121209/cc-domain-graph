# %% [markdown]
# # Playing with unicode

# %%
alphabet = range(1160, 1260)

for a in alphabet:
    b = unichr(a)
    c = ord(b)
    print(b + "\t%4d\t%4d\t%s" % (a, c, b.encode("utf-8").encode("hex")))
# Out:
# ҈	1160	1160	d288
# ҉	1161	1161	d289
# Ҋ	1162	1162	d28a
# ҋ	1163	1163	d28b
# Ҍ	1164	1164	d28c
# ҍ	1165	1165	d28d
# Ҏ	1166	1166	d28e
# ҏ	1167	1167	d28f
# Ґ	1168	1168	d290
# ґ	1169	1169	d291
# Ғ	1170	1170	d292
# ғ	1171	1171	d293
# Ҕ	1172	1172	d294
# ҕ	1173	1173	d295
# Җ	1174	1174	d296
# җ	1175	1175	d297
# Ҙ	1176	1176	d298
# ҙ	1177	1177	d299
# Қ	1178	1178	d29a
# қ	1179	1179	d29b
# Ҝ	1180	1180	d29c
# ҝ	1181	1181	d29d
# Ҟ	1182	1182	d29e
# ҟ	1183	1183	d29f
# Ҡ	1184	1184	d2a0
# ҡ	1185	1185	d2a1
# Ң	1186	1186	d2a2
# ң	1187	1187	d2a3
# Ҥ	1188	1188	d2a4
# ҥ	1189	1189	d2a5
# Ҧ	1190	1190	d2a6
# ҧ	1191	1191	d2a7
# Ҩ	1192	1192	d2a8
# ҩ	1193	1193	d2a9
# Ҫ	1194	1194	d2aa
# ҫ	1195	1195	d2ab
# Ҭ	1196	1196	d2ac
# ҭ	1197	1197	d2ad
# Ү	1198	1198	d2ae
# ү	1199	1199	d2af
# Ұ	1200	1200	d2b0
# ұ	1201	1201	d2b1
# Ҳ	1202	1202	d2b2
# ҳ	1203	1203	d2b3
# Ҵ	1204	1204	d2b4
# ҵ	1205	1205	d2b5
# Ҷ	1206	1206	d2b6
# ҷ	1207	1207	d2b7
# Ҹ	1208	1208	d2b8
# ҹ	1209	1209	d2b9
# Һ	1210	1210	d2ba
# һ	1211	1211	d2bb
# Ҽ	1212	1212	d2bc
# ҽ	1213	1213	d2bd
# Ҿ	1214	1214	d2be
# ҿ	1215	1215	d2bf
# Ӏ	1216	1216	d380
# Ӂ	1217	1217	d381
# ӂ	1218	1218	d382
# Ӄ	1219	1219	d383
# ӄ	1220	1220	d384
# Ӆ	1221	1221	d385
# ӆ	1222	1222	d386
# Ӈ	1223	1223	d387
# ӈ	1224	1224	d388
# Ӊ	1225	1225	d389
# ӊ	1226	1226	d38a
# Ӌ	1227	1227	d38b
# ӌ	1228	1228	d38c
# Ӎ	1229	1229	d38d
# ӎ	1230	1230	d38e
# ӏ	1231	1231	d38f
# Ӑ	1232	1232	d390
# ӑ	1233	1233	d391
# Ӓ	1234	1234	d392
# ӓ	1235	1235	d393
# Ӕ	1236	1236	d394
# ӕ	1237	1237	d395
# Ӗ	1238	1238	d396
# ӗ	1239	1239	d397
# Ә	1240	1240	d398
# ә	1241	1241	d399
# Ӛ	1242	1242	d39a
# ӛ	1243	1243	d39b
# Ӝ	1244	1244	d39c
# ӝ	1245	1245	d39d
# Ӟ	1246	1246	d39e
# ӟ	1247	1247	d39f
# Ӡ	1248	1248	d3a0
# ӡ	1249	1249	d3a1
# Ӣ	1250	1250	d3a2
# ӣ	1251	1251	d3a3
# Ӥ	1252	1252	d3a4
# ӥ	1253	1253	d3a5
# Ӧ	1254	1254	d3a6
# ӧ	1255	1255	d3a7
# Ө	1256	1256	d3a8
# ө	1257	1257	d3a9
# Ӫ	1258	1258	d3aa
# ӫ	1259	1259	d3ab

# %% [markdown]
# Note that the hex encodings are <b>not</b> the same as the indices in general!
#
# Some examples:

# %%
index = [range(35,41),
    range(65,71),
    range(188, 194),
    range(945, 951),
    range(1075, 1081),
    range(1900, 1906),
    range(2335, 2341),
    range(13351, 13357)]

print('---------------------------------------------')
for idx in index:
    print('\t'.join([unichr(x) for x in idx]))
    print('\t'.join([unichr(x).encode("utf-8").encode("hex") for x in idx]))
    print('---------------------------------------------')
# Out:
# ---------------------------------------------
# #	$	%	&	'	(
# 23	24	25	26	27	28
# ---------------------------------------------
# A	B	C	D	E	F
# 41	42	43	44	45	46
# ---------------------------------------------
# ¼	½	¾	¿	À	Á
# c2bc	c2bd	c2be	c2bf	c380	c381
# ---------------------------------------------
# α	β	γ	δ	ε	ζ
# ceb1	ceb2	ceb3	ceb4	ceb5	ceb6
# ---------------------------------------------
# г	д	е	ж	з	и
# d0b3	d0b4	d0b5	d0b6	d0b7	d0b8
# ---------------------------------------------
# ݬ	ݭ	ݮ	ݯ	ݰ	ݱ
# ddac	ddad	ddae	ddaf	ddb0	ddb1
# ---------------------------------------------
# ट	ठ	ड	ढ	ण	त
# e0a49f	e0a4a0	e0a4a1	e0a4a2	e0a4a3	e0a4a4
# ---------------------------------------------
# 㐧	㐨	㐩	㐪	㐫	㐬
# e390a7	e390a8	e390a9	e390aa	e390ab	e390ac
# ---------------------------------------------

# %% [markdown]
# Dump a string of these characters to a file for testing:

# %%
idx = index

str = ''.join([unichr(x[i]) for x in idx for i in range(6)])

f = open('test.txt', 'w')
f.write(str.encode('utf-8'))
f.close()

print(str.encode('utf-8'))
# Out:
# #$%&'(ABCDEF¼½¾¿ÀÁαβγδεζгдежзиݬݭݮݯݰݱटठडढणत㐧㐨㐩㐪㐫㐬

# %% [markdown]
# Note that the file can be read with <tt>cat</tt>, or viewed in hex with
#
# <tt>$ cat test.dat | hexdump</tt>
#
# To read back into Python:

# %%
import binascii

with open('test.txt', 'r') as f:
    content = f.read()

print(content.encode('hex'))
#print(binascii.hexlify(content))
#print(binascii.hexlify(str.encode('utf-8')))
#print(binascii.unhexlify(binascii.hexlify(content)))
#print(binascii.unhexlify(binascii.hexlify(content)).decode('utf-8'))
#print(binascii.unhexlify(binascii.hexlify(str.encode('utf-8'))).decode('utf-8'))
# Out:
# 232425262728414243444546c2bcc2bdc2bec2bfc380c381ceb1ceb2ceb3ceb4ceb5ceb6d0b3d0b4d0b5d0b6d0b7d0b8ddacddadddaeddafddb0ddb1e0a49fe0a4a0e0a4a1e0a4a2e0a4a3e0a4a4e390a7e390a8e390a9e390aae390abe390ac

# %% [markdown]
# We could use the package <tt>binascii</tt> but we don't need to.
#
# We can also iterate through the byte sequence:

# %%
' '.join([b.encode("hex") for b in content])
# Out:
# '23 24 25 26 27 28 41 42 43 44 45 46 c2 bc c2 bd c2 be c2 bf c3 80 c3 81 ce b1 ce b2 ce b3 ce b4 ce b5 ce b6 d0 b3 d0 b4 d0 b5 d0 b6 d0 b7 d0 b8 dd ac dd ad dd ae dd af dd b0 dd b1 e0 a4 9f e0 a4 a0 e0 a4 a1 e0 a4 a2 e0 a4 a3 e0 a4 a4 e3 90 a7 e3 90 a8 e3 90 a9 e3 90 aa e3 90 ab e3 90 ac'

# %%
from binascii import unhexlify

def hx(i):
    """
    Normalised 2-char hex representation of 0-255
    """
    a = hex(i)[2:]
    if len(a)<2: a = ''.join(['0',a])
    return a
hexabet = [hx(x) for x in range(256)]

hexstr = ' '.join([hx(int(b.encode("hex"), 16)) for b in content])

len(hexstr)
# Out:
# 287

# %%
for b in content:
    a = int(b.encode('hex'), 16)  # 16 is the base
    print("%s %4d" % (unichr(a), a))
# Out:
# #   35
# $   36
# %   37
# &   38
# '   39
# (   40
# A   65
# B   66
# C   67
# D   68
# E   69
# F   70
# Â  194
# ¼  188
# Â  194
# ½  189
# Â  194
# ¾  190
# Â  194
# ¿  191
# Ã  195
#   128
# Ã  195
#   129
# Î  206
# ±  177
# Î  206
# ²  178
# Î  206
# ³  179
# Î  206
# ´  180
# Î  206
# µ  181
# Î  206
# ¶  182
# Ð  208
# ³  179
# Ð  208
# ´  180
# Ð  208
# µ  181
# Ð  208
# ¶  182
# Ð  208
# ·  183
# Ð  208
# ¸  184
# Ý  221
# ¬  172
# Ý  221
# ­  173
# Ý  221
# ®  174
# Ý  221
# ¯  175
# Ý  221
# °  176
# Ý  221
# ±  177
# à  224
# ¤  164
#   159
# à  224
# ¤  164
#    160
# à  224
# ¤  164
# ¡  161
# à  224
# ¤  164
# ¢  162
# à  224
# ¤  164
# £  163
# à  224
# ¤  164
# ¤  164
# ã  227
#   144
# §  167
# ã  227
#   144
# ¨  168
# ã  227
#   144
# ©  169
# ã  227
#   144
# ª  170
# ã  227
#   144
# «  171
# ã  227
#   144
# ¬  172

# %% [markdown]
# Can we demarcate some of the separate non-Latin scripts?

# %%
def hx(a):
    return [x.encode('hex') for x in list(a.encode("utf-8"))]

rg = ['3040','309f'] # hiragana
#rg = ['0e00','0e7f'] # thai

for i in range(int(rg[0], 16), int(rg[1], 16)):
    a = unichr(i)
    h = hx(a)
    print(hex(i))
    print(a) 
    print(h)
# Out:
# 0x3040
# ぀
# ['e3', '81', '80']
# 0x3041
# ぁ
# ['e3', '81', '81']
# 0x3042
# あ
# ['e3', '81', '82']
# 0x3043
# ぃ
# ['e3', '81', '83']
# 0x3044
# い
# ['e3', '81', '84']
# 0x3045
# ぅ
# ['e3', '81', '85']
# 0x3046
# う
# ['e3', '81', '86']
# 0x3047
# ぇ
# ['e3', '81', '87']
# 0x3048
# え
# ['e3', '81', '88']
# 0x3049
# ぉ
# ['e3', '81', '89']
# 0x304a
# お
# ['e3', '81', '8a']
# 0x304b
# か
# ['e3', '81', '8b']
# 0x304c
# が
# ['e3', '81', '8c']
# 0x304d
# き
# ['e3', '81', '8d']
# 0x304e
# ぎ
# ['e3', '81', '8e']
# 0x304f
# く
# ['e3', '81', '8f']
# 0x3050
# ぐ
# ['e3', '81', '90']
# 0x3051
# け
# ['e3', '81', '91']
# 0x3052
# げ
# ['e3', '81', '92']
# 0x3053
# こ
# ['e3', '81', '93']
# 0x3054
# ご
# ['e3', '81', '94']
# 0x3055
# さ
# ['e3', '81', '95']
# 0x3056
# ざ
# ['e3', '81', '96']
# 0x3057
# し
# ['e3', '81', '97']
# 0x3058
# じ
# ['e3', '81', '98']
# 0x3059
# す
# ['e3', '81', '99']
# 0x305a
# ず
# ['e3', '81', '9a']
# 0x305b
# せ
# ['e3', '81', '9b']
# 0x305c
# ぜ
# ['e3', '81', '9c']
# 0x305d
# そ
# ['e3', '81', '9d']
# 0x305e
# ぞ
# ['e3', '81', '9e']
# 0x305f
# た
# ['e3', '81', '9f']
# 0x3060
# だ
# ['e3', '81', 'a0']
# 0x3061
# ち
# ['e3', '81', 'a1']
# 0x3062
# ぢ
# ['e3', '81', 'a2']
# 0x3063
# っ
# ['e3', '81', 'a3']
# 0x3064
# つ
# ['e3', '81', 'a4']
# 0x3065
# づ
# ['e3', '81', 'a5']
# 0x3066
# て
# ['e3', '81', 'a6']
# 0x3067
# で
# ['e3', '81', 'a7']
# 0x3068
# と
# ['e3', '81', 'a8']
# 0x3069
# ど
# ['e3', '81', 'a9']
# 0x306a
# な
# ['e3', '81', 'aa']
# 0x306b
# に
# ['e3', '81', 'ab']
# 0x306c
# ぬ
# ['e3', '81', 'ac']
# 0x306d
# ね
# ['e3', '81', 'ad']
# 0x306e
# の
# ['e3', '81', 'ae']
# 0x306f
# は
# ['e3', '81', 'af']
# 0x3070
# ば
# ['e3', '81', 'b0']
# 0x3071
# ぱ
# ['e3', '81', 'b1']
# 0x3072
# ひ
# ['e3', '81', 'b2']
# 0x3073
# び
# ['e3', '81', 'b3']
# 0x3074
# ぴ
# ['e3', '81', 'b4']
# 0x3075
# ふ
# ['e3', '81', 'b5']
# 0x3076
# ぶ
# ['e3', '81', 'b6']
# 0x3077
# ぷ
# ['e3', '81', 'b7']
# 0x3078
# へ
# ['e3', '81', 'b8']
# 0x3079
# べ
# ['e3', '81', 'b9']
# 0x307a
# ぺ
# ['e3', '81', 'ba']
# 0x307b
# ほ
# ['e3', '81', 'bb']
# 0x307c
# ぼ
# ['e3', '81', 'bc']
# 0x307d
# ぽ
# ['e3', '81', 'bd']
# 0x307e
# ま
# ['e3', '81', 'be']
# 0x307f
# み
# ['e3', '81', 'bf']
# 0x3080
# む
# ['e3', '82', '80']
# 0x3081
# め
# ['e3', '82', '81']
# 0x3082
# も
# ['e3', '82', '82']
# 0x3083
# ゃ
# ['e3', '82', '83']
# 0x3084
# や
# ['e3', '82', '84']
# 0x3085
# ゅ
# ['e3', '82', '85']
# 0x3086
# ゆ
# ['e3', '82', '86']
# 0x3087
# ょ
# ['e3', '82', '87']
# 0x3088
# よ
# ['e3', '82', '88']
# 0x3089
# ら
# ['e3', '82', '89']
# 0x308a
# り
# ['e3', '82', '8a']
# 0x308b
# る
# ['e3', '82', '8b']
# 0x308c
# れ
# ['e3', '82', '8c']
# 0x308d
# ろ
# ['e3', '82', '8d']
# 0x308e
# ゎ
# ['e3', '82', '8e']
# 0x308f
# わ
# ['e3', '82', '8f']
# 0x3090
# ゐ
# ['e3', '82', '90']
# 0x3091
# ゑ
# ['e3', '82', '91']
# 0x3092
# を
# ['e3', '82', '92']
# 0x3093
# ん
# ['e3', '82', '93']
# 0x3094
# ゔ
# ['e3', '82', '94']
# 0x3095
# ゕ
# ['e3', '82', '95']
# 0x3096
# ゖ
# ['e3', '82', '96']
# 0x3097
# ゗
# ['e3', '82', '97']
# 0x3098
# ゘
# ['e3', '82', '98']
# 0x3099
# ゙
# ['e3', '82', '99']
# 0x309a
# ゚
# ['e3', '82', '9a']
# 0x309b
# ゛
# ['e3', '82', '9b']
# 0x309c
# ゜
# ['e3', '82', '9c']
# 0x309d
# ゝ
# ['e3', '82', '9d']
# 0x309e
# ゞ
# ['e3', '82', '9e']

# %%
import csv

lookup_file = "./unicode_ranges.txt"
lookup_script = ['' for i in range(1000000)]
lookup_range = {}

with open(lookup_file) as tsv:
    for line in csv.reader(tsv, delimiter='\t'): 
        mn = int(line[0], 16)
        mx = int(line[1], 16)
        lookup_range[line[2]] = [mn, mx+1]
        for i in range(mn, mx+1):
            lookup_script[i] = line[2]

lookup_range
# Out:
# {'Aegean Numbers': [65792, 65856],
#  'Alphabetic Presentation Forms': [64256, 64336],
#  'Arabic': [1536, 1792],
#  'Arabic Presentation Forms-A': [64336, 65024],
#  'Arabic Presentation Forms-B': [65136, 65280],
#  'Armenian': [1328, 1424],
#  'Arrows': [8592, 8704],
#  'Basic Latin': [32, 128],
#  'Bengali': [2432, 2560],
#  'Block Elements': [9600, 9632],
#  'Bopomofo': [12544, 12592],
#  'Bopomofo Extended': [12704, 12736],
#  'Box Drawing': [9472, 9600],
#  'Braille Patterns': [10240, 10496],
#  'Buhid': [5952, 5984],
#  'Byzantine Musical Symbols': [118784, 119040],
#  'CJK Compatibility': [13056, 13312],
#  'CJK Compatibility Forms': [65072, 65104],
#  'CJK Compatibility Ideographs': [63744, 64256],
#  'CJK Compatibility Ideographs Supplement': [194560, 195104],
#  'CJK Radicals Supplement': [11904, 12032],
#  'CJK Symbols and Punctuation': [12288, 12352],
#  'CJK Unified Ideographs': [19968, 40960],
#  'CJK Unified Ideographs Extension A': [13312, 19904],
#  'CJK Unified Ideographs Extension B': [131072, 173792],
#  'Cherokee': [5024, 5120],
#  'Combining Diacritical Marks': [768, 880],
#  'Combining Diacritical Marks for Symbols': [8400, 8448],
#  'Combining Half Marks': [65056, 65072],
#  'Control Pictures': [9216, 9280],
#  'Currency Symbols': [8352, 8400],
#  'Cypriot Syllabary': [67584, 67648],
#  'Cyrillic': [1024, 1280],
#  'Cyrillic Supplementary': [1280, 1328],
#  'Deseret': [66560, 66640],
#  'Devanagari': [2304, 2432],
#  'Dingbats': [9984, 10176],
#  'Enclosed Alphanumerics': [9312, 9472],
#  'Enclosed CJK Letters and Months': [12800, 13056],
#  'Ethiopic': [4608, 4992],
#  'General Punctuation': [8192, 8304],
#  'Geometric Shapes': [9632, 9728],
#  'Georgian': [4256, 4352],
#  'Gothic': [66352, 66384],
#  'Greek Extended': [7936, 8192],
#  'Greek and Coptic': [880, 1024],
#  'Gujarati': [2688, 2816],
#  'Gurmukhi': [2560, 2688],
#  'Halfwidth and Fullwidth Forms': [65280, 65520],
#  'Hangul Compatibility Jamo': [12592, 12688],
#  'Hangul Jamo': [4352, 4608],
#  'Hangul Syllables': [44032, 55216],
#  'Hanunoo': [5920, 5952],
#  'Hebrew': [1424, 1536],
#  'High Private Use Surrogates': [56192, 56320],
#  'High Surrogates': [55296, 56192],
#  'Hiragana': [12352, 12448],
#  'IPA Extensions': [592, 688],
#  'Ideographic Description Characters': [12272, 12288],
#  'Kanbun': [12688, 12704],
#  'Kangxi Radicals': [12032, 12256],
#  'Kannada': [3200, 3328],
#  'Katakana': [12448, 12544],
#  'Katakana Phonetic Extensions': [12784, 12800],
#  'Khmer': [6016, 6144],
#  'Khmer Symbols': [6624, 6656],
#  'Lao': [3712, 3840],
#  'Latin Extended Additional': [7680, 7936],
#  'Latin Extended-A': [256, 384],
#  'Latin Extended-B': [384, 592],
#  'Latin-1 Supplement': [160, 256],
#  'Letterlike Symbols': [8448, 8528],
#  'Limbu': [6400, 6480],
#  'Linear B Ideograms': [65664, 65792],
#  'Linear B Syllabary': [65536, 65664],
#  'Low Surrogates': [56320, 57344],
#  'Malayalam': [3328, 3456],
#  'Mathematical Alphanumeric Symbols': [119808, 120832],
#  'Mathematical Operators': [8704, 8960],
#  'Miscellaneous Mathematical Symbols-A': [10176, 10224],
#  'Miscellaneous Mathematical Symbols-B': [10624, 10752],
#  'Miscellaneous Symbols': [9728, 9984],
#  'Miscellaneous Symbols and Arrows': [11008, 11264],
#  'Miscellaneous Technical': [8960, 9216],
#  'Mongolian': [6144, 6320],
#  'Musical Symbols': [119040, 119296],
#  'Myanmar': [4096, 4256],
#  'Number Forms': [8528, 8592],
#  'Ogham': [5760, 5792],
#  'Old Italic': [66304, 66352],
#  'Optical Character Recognition': [9280, 9312],
#  'Oriya': [2816, 2944],
#  'Osmanya': [66688, 66736],
#  'Phonetic Extensions': [7424, 7552],
#  'Private Use Area': [57344, 63744],
#  'Runic': [5792, 5888],
#  'Shavian': [66640, 66688],
#  'Sinhala': [3456, 3584],
#  'Small Form Variants': [65104, 65136],
#  'Spacing Modifier Letters': [688, 768],
#  'Specials': [65520, 65536],
#  'Superscripts and Subscripts': [8304, 8352],
#  'Supplemental Arrows-A': [10224, 10240],
#  'Supplemental Arrows-B': [10496, 10624],
#  'Supplemental Mathematical Operators': [10752, 11008],
#  'Syriac': [1792, 1872],
#  'Tagalog': [5888, 5920],
#  'Tagbanwa': [5984, 6016],
#  'Tags': [917504, 917632],
#  'Tai Le': [6480, 6528],
#  'Tai Xuan Jing Symbols': [119552, 119648],
#  'Tamil': [2944, 3072],
#  'Telugu': [3072, 3200],
#  'Thaana': [1920, 1984],
#  'Thai': [3584, 3712],
#  'Tibetan': [3840, 4096],
#  'Ugaritic': [66432, 66464],
#  'Unified Canadian Aboriginal Syllabics': [5120, 5760],
#  'Variation Selectors': [65024, 65040],
#  'Yi Radicals': [42128, 42192],
#  'Yi Syllables': [40960, 42128],
#  'Yijing Hexagram Symbols': [19904, 19968]}

# %%
def find_scripts(content):
    d = {}
    for c in content:
        s = lookup_script[ord(c)]
        if not s in d.keys(): d[s] = 0
        d[s] += 1
    return d

ex = 'Arabic'

mn = lookup_range[ex][0]
mx = lookup_range[ex][1]

str = ''.join([unichr(i) for i in range(mn, mx)])
print(str)

print(find_scripts(str))
# Out:
# ؀؁؂؃؄؅؆؇؈؉؊؋،؍؎؏ؘؙؚؐؑؒؓؔؕؖؗ؛؜؝؞؟ؠءآأؤإئابةتثجحخدذرزسشصضطظعغػؼؽؾؿـفقكلمنهوىيًٌٍَُِّْٕٖٜٟٓٔٗ٘ٙٚٛٝٞ٠١٢٣٤٥٦٧٨٩٪٫٬٭ٮٯٰٱٲٳٴٵٶٷٸٹٺٻټٽپٿڀځڂڃڄڅچڇڈډڊڋڌڍڎڏڐڑڒړڔڕږڗژڙښڛڜڝڞڟڠڡڢڣڤڥڦڧڨکڪګڬڭڮگڰڱڲڳڴڵڶڷڸڹںڻڼڽھڿۀہۂۃۄۅۆۇۈۉۊۋیۍێۏېۑےۓ۔ەۖۗۘۙۚۛۜ۝۞ۣ۟۠ۡۢۤۥۦۧۨ۩۪ۭ۫۬ۮۯ۰۱۲۳۴۵۶۷۸۹ۺۻۼ۽۾ۿ
# {'Arabic': 256}

# %%
from pprint import pprint

str = ''.join([unichr(i) for i in range(4000)])

pprint(find_scripts(str))
# Out:
# {'': 432,
#  'Arabic': 256,
#  'Armenian': 96,
#  'Basic Latin': 96,
#  'Bengali': 128,
#  'Combining Diacritical Marks': 112,
#  'Cyrillic': 256,
#  'Cyrillic Supplementary': 48,
#  'Devanagari': 128,
#  'Greek and Coptic': 144,
#  'Gujarati': 128,
#  'Gurmukhi': 128,
#  'Hebrew': 112,
#  'IPA Extensions': 96,
#  'Kannada': 128,
#  'Lao': 128,
#  'Latin Extended-A': 128,
#  'Latin Extended-B': 208,
#  'Latin-1 Supplement': 96,
#  'Malayalam': 128,
#  'Oriya': 128,
#  'Sinhala': 128,
#  'Spacing Modifier Letters': 80,
#  'Syriac': 80,
#  'Tamil': 128,
#  'Telugu': 128,
#  'Thaana': 64,
#  'Thai': 128,
#  'Tibetan': 160}

# %% [markdown]
# How to translate bytes to integers and integers back to bytes and UTF-8:

# %%
pathfile = "../img/URIs/high_langdet_URIs_1.txt"

with open(pathfile, 'r') as f:
    raw_str = f.read()

bytes = [int(b.encode('hex'), 16) for b in raw_str]
content = bytearray(bytes)

#print(content)

# %% [markdown]
# To identify the scripts, decode the raw data as unicode:

# %%
from pprint import pprint

find_scripts(raw_str.decode('utf-8'))
# Out:
# {'': 2205,
#  'Arabic': 10011,
#  'Basic Latin': 56708,
#  'CJK Symbols and Punctuation': 19,
#  'CJK Unified Ideographs': 1446,
#  'Cyrillic': 7365,
#  'General Punctuation': 97,
#  'Greek and Coptic': 177,
#  'Halfwidth and Fullwidth Forms': 5,
#  'Hangul Syllables': 94,
#  'Hebrew': 68,
#  'Hiragana': 57,
#  'Katakana': 142,
#  'Latin Extended-A': 3,
#  'Latin-1 Supplement': 28,
#  'Letterlike Symbols': 2,
#  'Mathematical Operators': 14,
#  'Thai': 853}

# %%
script = 'Cyrillic'

with open(pathfile, 'r') as f:
    contents = f.readlines()
    
for line in contents[:200]:
    scripts = find_scripts(line.decode('utf-8'))
    if script in scripts.keys():
        print line[:-1] # -1 drops the newline
# Out:
# /Категория:Земли Иннадрила - квесты
# /post/104336621613/рига-тревелмевел-памятник-архитектура
# /post/104336931293/рига-тревелмевел-нг-елка-новыйгод-зима
# www.биовод.рф (0.470588)
# мебельный.рф (0.6875)
# /post/130256928869/рижанка
# /post/111864260364/а-из-этого-окна-riga-разная-видна-latvia-рига

# %% [markdown]
# Here's the script distribution for the RNN training file:

# %%
import gzip

pathfile = "../sdata/big_domain_string_1_with_nonlatin_1pt05_12287_1024.gz"

with gzip.open(pathfile, "rb") as f:
    content = f.read().decode('utf-8')

script_dict = find_scripts(content)

for k,v in sorted(script_dict.iteritems(), key=lambda (k,v): (-v,k)):
    print "%10d: %s" % (v, k)
# Out:
#  199085196: Basic Latin
#   15178683: Arabic
#   12699963: Cyrillic
#    5739364:
#    2358079: Thai
#    1843757: CJK Unified Ideographs
#    1005245: Greek and Coptic
#     961990: Katakana
#     386203: Hebrew
#     323816: Hangul Syllables
#     246429: Latin-1 Supplement
#     232405: Bengali
#     213798: Hiragana
#     117852: Devanagari
#     102710: Latin Extended-A
#      83337: CJK Symbols and Punctuation
#      44544: General Punctuation
#      42741: Latin Extended Additional
#      33620: Halfwidth and Fullwidth Forms
#      21187: Telugu
#      20166: Georgian
#      19509: Armenian
#      16985: Tamil
#      14440: Hangul Jamo
#       9940: Latin Extended-B
#       6529: Myanmar
#       6403: IPA Extensions
#       4962: Specials
#       3811: Gujarati
#       3658: Kannada
#       2668: Letterlike Symbols
#       2166: Khmer
#       2024: Sinhala
#       1909: Arabic Presentation Forms-B
#       1802: Spacing Modifier Letters
#       1792: Currency Symbols
#       1688: Miscellaneous Symbols
#       1451: Lao
#       1378: Combining Diacritical Marks
#       1242: Ethiopic
#       1165: Gurmukhi
#        901: Enclosed Alphanumerics
#        814: Malayalam
#        641: Low Surrogates
#        637: High Surrogates
#        484: Geometric Shapes
#        407: Dingbats
#        360: Arrows
#        279: Mathematical Operators
#        259: Box Drawing
#        201: Hangul Compatibility Jamo
#        189: CJK Unified Ideographs Extension A
#        132: Arabic Presentation Forms-A
#        111: Variation Selectors
#         97: Phonetic Extensions
#         91: Number Forms
#         75: Block Elements
#         56: Private Use Area
#         30: Bopomofo
#         24: Enclosed CJK Letters and Months
#         23: Superscripts and Subscripts
#         21: CJK Compatibility Forms
#         21: Greek Extended
#         18: CJK Compatibility Ideographs
#         16: Alphabetic Presentation Forms
#         12: Small Form Variants
#         11: CJK Compatibility
#         11: Unified Canadian Aboriginal Syllabics
#         11: Yi Syllables
#          9: Oriya
#          8: Supplemental Mathematical Operators
#          6: Miscellaneous Symbols and Arrows
#          6: Yi Radicals
#          4: High Private Use Surrogates
#          3: Cyrillic Supplementary
#          3: Miscellaneous Technical
#          2: Braille Patterns
#          2: Miscellaneous Mathematical Symbols-B
#          2: Syriac
#          2: Thaana
#          2: Tibetan
#          1: Kanbun
#          1: Kangxi Radicals
#          1: Katakana Phonetic Extensions

# %% [markdown]
# Let's explore some of the exotic instances:

# %%
lines = ''.join(content).split('\n')

# %%
target_script = 'Ethiopic'

maxlines = 100
for line in lines:
    if maxlines <= 0: break
    scripts = find_scripts(line)
    if target_script in scripts.keys():
        print line[:-1] # -1 drops the newline
        maxlines -= 1
# Out:
# /donwload/mp3/eW91dHViZS0wMVZEN0xpcnlDOA-ግለ-ወሲብ-እራስን-በራስ-ማርካት-በወጣቶች-ላይ-ጉዳትና-ጥቅም
# /donwload/mp3/eW91dHViZS1BaldWUTgyWnJEaw-ግለ-ወሲብ-ወይም-ራስን-ማርካት-በፍቅር-ግኑኝነት-ላይ-ያለው-ተጽዕኖ-ምንድነው-በባለሙያው-አቶ-ጌታቸው-በትራስ-ሹሹክታ
# /donwload/mp3/eW91dHViZS1Cc0hyS1lYTGx0aw-አዲስ-አበባ-መኪና-ውስጥ-ወሲብ-ሲፈጽሙ-በፖሊስ-ተያዙ
# /donwload/mp3/eW91dHViZS1LQWF1djA1X29MSQ-የሰባተኛ-ወሲብ-ቤቶች-ደንበኞች-እነማን-ይሆኑ
# /donwload/mp3/eW91dHViZS1MOTk5Wk4tQjFybw-ከባዶ-ይሻላል-አለ-ምን-አይነት-ሰው-ነው-ለሴት-ልጅ-ክብር-ስጥ
# /donwload/mp3/eW91dHViZS1MRjFMU3RIbWRLWQ-እስልምና-ከ-9-ዓመት-ሴት-ልጅ-ጋር-ወሲብ-ይፈቅዳል
# /donwload/mp3/eW91dHViZS1ZOXRnUHJvbGJTSQ-ቶሎ-እረጫለሁ-ገና-ስተሻሽ-ብልቴን-ያቃጥለኛል-ሴክስ-ላይ-ሀይለኛ-ነኝ-ፍቅረኛዬ-ትፈራኛለች-እና-ሌሎችም-የፍቅር-ጉዳዩች-zami-fm
# /donwload/mp3/eW91dHViZS1abXpzOWMyM0xHTQ-የወንድና-ሴት-ብልት-ያላት-ወንድንም-ሴትንም-ሴክስ-የሚያረጉ-ሴተኛ-አዳሪዋ-ፊልም-ልትሰራ-ስትል-አርቲስቶች-ወሲብ-የጠየቋት-የተአምረኛዋ-ሳራ-የሚገርም-ታሪክ
# /donwload/mp3/eW91dHViZS1mcndjaGYzMzl5QQ-የስንፈተ-ወሲብ-መድሓኒትቪያግራ-ጥቅሙና-ጉዳቱ-shegerfm
# /donwload/mp3/eW91dHViZS1zZzR0X29pQ3JnUQ-ፍቅር-እና-ወሲብ-ከትዳር-በፊት-ቡሃላ
# /search/mp3/የኢትዮጵያ-ወሲብ.htm
# /video/mogachoch--ሞጋቾች--69.htm
# /video/ላመልክሀ-የተገባህ-live-cover.htm
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/bailiff
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ሌሎች-መጠጦ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/መንግስት-ተቋማት-
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/መገልገያዎች-
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ማስታወቂያ-በማተም-ላ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ማስፈጸ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ቅርሶ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/በውጭ-አገር-የዕዳ-ክምች
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/በይሊፍ-ቢሮዎ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ቢ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ቪንቴጅ-ንጥሎ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ቴምብ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ነዳ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/አልኮ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/አማራጭ-የኃይ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ኢነርጂ-እና-የተፈጥሮ-ሀብ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ኤምባሲዎ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ዕቃዎች-ንግ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የመዋኛ-ገንዳዎ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የሥርዓት-ሰነዶ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የቅርስ-ዕቃዎ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የቆሻሻ-እቃዎ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የቆየ-የቤት-ዕ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የአካባቢ-አስተዳደ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የአካባቢ-አቀማመ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የዕዳ-ክምች
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/የድሮ-ወረቀ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ድንጋይ-ምርቶ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ግብርና-የምግብ-ምርቶ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ግንባታ-የሪል-እስቴ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ጥበብ-ሥራዎ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ጥንታ
# /am/የመስመር-ላይ-የንግድ-ካርድ-ካታሎግ/ፋይናንስ-ኢንሹራንስ-ሕ
# /video/mogachoch--ሞጋቾች--69.htm
