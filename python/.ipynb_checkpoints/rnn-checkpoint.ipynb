# %% [markdown]
# # RNN model of URIs

# %% [markdown]
# The Python code from this notebook has now been developed into two scripts
# <ol>
# <li> <tt>train_rnn.py</tt>
# <code>
# Usage: python  ./python/train_rnn.py infile [options]
# Options are:
#         -o outfile
#         -datapath [./sdata]
#         -modelpath [./models]
#         -unroll [20]
#         -step [3]
#         -dropout [0.1]
#         -niters [10]
#         -arch (hidden layer sizes) [16]
# </code>
# <li> <tt>make_synthetic.py</tt>
# <code>
# Usage: python  ./python/make_synthetic.py infile [options]
# Options are:
#         -n length of output [1000]
#         -init        [newlines]
#         -temp        [1.0]
#         -modelpath        [./models]
# </ol>

# %% [markdown]
# ## Training a model

# %%
run -i train_rnn\
    smallstring.gz\
    -datapath ../sdata\
    -modelpath ../models\
    -arch 32,32\
    -niters 16
# Out:
# Checking hardware ...
# [name: "/cpu:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11201530596252466535
# ]
# Model architecture:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 20, 32)            5248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 32)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               8448
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# =================================================================
# Total params: 22,016
# Trainable params: 22,016
# Non-trainable params: 0
# _________________________________________________________________
# None
# Can't find existing model, initialising random weights
# Reading data file ../sdata/smallstring.gz ...
# Read 10000 bytes in 0.013794 seconds
# Cutting into byte sequences of size 20 ...
# Written 3327 sequences in 0.005031 seconds
# Formatting arrays ...
# Arrays written in 0.072629 seconds
# Fitting model ...
# Epoch block 0:
# Epoch 1/5
# 3327/3327 [==============================] - 5s - loss: 4.8256
# Epoch 2/5
# 3327/3327 [==============================] - 3s - loss: 3.8918
# Epoch 3/5
# 3327/3327 [==============================] - 5s - loss: 3.6957
# Epoch 4/5
# 3327/3327 [==============================] - 4s - loss: 3.6272
# Epoch 5/5
# 3327/3327 [==============================] - 4s - loss: 3.6063
# Epoch block 1:
# Epoch 1/5
# 3327/3327 [==============================] - 3s - loss: 3.5891
# Epoch 2/5
# 3327/3327 [==============================] - 3s - loss: 3.5783
# Epoch 3/5
# 3327/3327 [==============================] - 3s - loss: 3.5687
# Epoch 4/5
# 3327/3327 [==============================] - 3s - loss: 3.5576
# Epoch 5/5
# 3327/3327 [==============================] - 3s - loss: 3.5484
# Epoch block 2:
# Epoch 1/5
# 3327/3327 [==============================] - 3s - loss: 3.5418
# Epoch 2/5
# 3327/3327 [==============================] - 3s - loss: 3.5366
# Epoch 3/5
# 3327/3327 [==============================] - 3s - loss: 3.5269
# Epoch 4/5
# 3327/3327 [==============================] - 3s - loss: 3.5232
# Epoch 5/5
# 3327/3327 [==============================] - 3s - loss: 3.5180
# Epoch block 3:
# Epoch 1/1
# 3327/3327 [==============================] - 3s - loss: 3.5170
# Done in 119.908 seconds
# Model written to ../models/model_from_smallstring.gz_arch_8_32_32_unroll_20_step_3_dropout_0.1

# %% [markdown]
# ## Synthetic domain string from model

# %%
run -i make_synthetic\
    model_from_big_domain_string_1.gz_arch_8_32_32_unroll_20_step_3_dropout_0.1_iter_30.npy\
    -modelpath ../models\
    -init '叶问前传BD国语中字1024高清'\
    -temp 1.2\
    -n 4000
# Out:
# 叶问前传BD国语中字1024高清--/daalBaple/0692026-240sizle.html
# /lighles/com-trm/vanogca-tad/cu213.html
# /images/282/0202415/14x32.html
# /87Hetondudecairre
# /882.ed
# /424/fssyuer-520.html
# /ovet/eander9-22314/t/9N26/XN7B8673_
# /k17hasheS
#
#
#
# sclijk1.gofoty.skorrkki-i%d6%55b-0-058d04e9032pb5..p/2003/images/propran/25.am
#
#
#
# kwsFhyarroira_nrbridargen.png
# /Chbror_forgarlemirimagengrret
# /plm/ggitor/
# /seilagi/senlen-seartic_bham_hy.kobeniz.cbmmskrseev.org
# /p-hm.gif
# /h/compi1/
#
#
#
# owSnoxb
# w64n.upasEgo.html/
# /product/5/8d0/3751
# /f1_GiZ0950758a003968ca_1.6p/19344/610-pecHica-capc4-.olsxe
# /fs-pedodets.su
# /masiu
# /kkau-h-dnil0x2/
# /itel_2909/30/imagel/fraber
# /aesbrgaa/1581.html
# /category/ksun-unasu/jeliwehcondping/down
# /wy/ritur-lidica/goloste//
# /abiland/
#
#
#
# www.vuan/ribato
# /kirs/conyh-8023-20/
# /viebstast
# /s//xe/fl6/2013/18.html
# /cars-noirkip
# /seelossB-brai-membboetsnabJia.kajepas_iThef-21b15q022%cyz6hl9.jpg
# /images/D533585057da09ef39e07.ct
# /T-Ppn1301027BIAELan-Ltqe-verd-2004Dl0zu1Lts
# /
# /skKtmsheb-74024
# /spotma/aoner.nat
# /category/nena/repramcb
# /pt/tjaies.jpg
# /
#
#
#
# uchnungr.5czate-bts.ZAms94x3q/hlogiis
# /music/ut-rilredes//2272.jpg
# /ezdap_mhu/ph930/6it-avind-atargs-odretwarakn-skrn/0x31010rl54Iu9T8q004-hd-/tofomimorhy-jonide-patery-produids/b48931e7.gpm__scapvic.com
# /vpledirtomes/suardoho-b/18700
#
#
#
# www.ucbibiEyrob.cu
# /wp.sholes/ardmavlay-aboks-pomach-an
# /axfalmaath-gUsb-4231/1mz/i/2019/1f/1.html
# /siser.html
# /foron/sesskozuy
# /caom/mhoyu/vc.jpg
# /tid-fatienter/rird-orefkhtukistaye.htmn_moeinilm.cuwo1-appravenel/zes-Orz1av67j0o292LC6
# /IsLgsuase/C/5Mongi
# /os-cards-B%2Gb-CPRocS1709_DI00XC
# /MetyTot_mestoldlittupS/bayer_pos_Peviee-Dimolibriuu_josIor.gif
# /330/fatemeot.html
# /er/stu2s8-ttdation-109/peakh2339.gif
# /2cbk/warebsun-asslic-esiasesss/gast/1/12788/fow/%-33019m83.jpg
# /pic/bomest/5621609/Italnne-le_m.html
# /chans-lelr/stock/kusagvosisa6-c
# /kamallek/OPRN_moflia_zymiIn_11BKD3Em_CAR.ctm
# /SMoWBEY8304/10021.rps3175-3ey7bf419354598f90751aaef68e01eb.t7upvhcaax
#
#
#
# ewap.nilfqgofigrontendaar/18a
# /pfory/
# /empeathons5vltjwjcoundtome_nyl_Dj5IAlChMRRkoftmAzl0oylm-n9%2W326E.html
# /1/001066034305/0/0/gydah/sofecA_Iuleen-LenniC-BF/
# /i100/_fuctoriki/neudy_Conlitamiases
# /payetculv
# /pastre-yactivatnorova-iphroutle-giini.
# /408roke-uimn-5/
# /wl/procoss-5-ls/ipily-men-itera-adaT-tadbaoel-pitura-des.html
# /storabal/mikaus-peg-nl-
# /Licd.ONsUX+Z60Vj83JHiuGiz-7ldlSf/Dot.html
# /2k60-.gif
# /promidk/catb0/rfmalen-uled-koxisdlhob
# /lients/c8454d40/-Ter-403.jpg
# /2ps/hidic/basi/Blogue.html
#
#
#
# vrager.-deamodle_blogvitciL_vhamZt1s.tZss-page141.png
# /cUulrs-fer-80280908868050757_e-1682eb07b_28812c.jpg
#
#
#
# www.h
# /chif-kenplenk/
# /mebuid
# /gil21065/1206559310_.html
# /capk/coms
# /Sqearde/201495/a74471811318432317_44053732779851069302601G%E1
#
#
#
# smavmshots.ct1
#
#
#
# pome.felrion.gi-hobrancoiisconc6685.jpg
# /wp-cker/deader2tklmato.kiemtemraj452s-diidprot-reegad.html
# /omarrseapbal-10refa-miad-pagatn
# /r/pwn102604/m_C.pfg
# /bwowba/so1t5y065/home/Mitreizkasse-Alcpisord-1800_traathna
# /ayleeepartbaniiibap
# /eleott-hom0-754.jpg
# /blog-lipstic--mentaja-clates-tewtai
# /adticia-daner
# /demlisoda-runa1pshgiysst-serco_refboaberm.htm
# /cat%80%84-%l3%b4%d8%aa/%d9%86-%d8%b6%d8%b3%d8%a3%d8%a4%db%8c%d8%99%d8%af%d9%83-rarm-de-Mevy-tine-sebnei%d1%b7
# /2018-scourqh-347b1b2998u5f3J3824.jpg
# /partverbaur/
# /creal559
# /fo7417/mols_resorits.php
# /02/05/12a/kapzac79V.AiIMFbR_ke.html
# /v_bacture_2206_nrove.jpg
# /400/jLss.png
# /P/4gaudnushxs_S-7D
# /ef/protuonm/teas/oaskalwal/haspust-chencida-yerole-mu107
# /Conmardia.png/Hliyhor_002hea.jpg
# /asseonauky
# /s/zere-peu-frewers/thedicatoynitenen__as_Uromeled-b504P5BD4r/Umg/QorShhoter-pemani-unfhraddy-dbslmunafo/spiac-sirva-i/diCfsIC-ogi-T-910rn3bhu-brusu_tafeuci
# /RuarFyliwt
# /Touna-Eiron/1900.jpg
# /si/948440.html
# /vomm-frezar-an%3cc1b241dmf60.html
# /ad-.psn.html
#
#
#
# slaga-ilel.com
#
#
#
#
# www.b5am2tun/rewers/olpefeczpbol-ursambtulir
# /6445-ratorivolcamaiku5+latets/my.html
# /prododgerucnaturo-actiden
# /bueaahag-hox/itad-rigionle/aqproado_0.html
# /yuzerd-chav3-hatesol-LeSAS7Dt.95/paretaty/5
# /Imc-2na_2789374.html
# /tivpi.html
# /2026/11/0/326292/147_37934o

# %% [markdown]
# ## Entropy of the model

# %% [markdown]
# How do we assess the performance of a model?
#
# Below I'm using code from <tt>make_synthetic.py</tt> to compute the average prediction entropy on a test string of 10k bytes.
#
# The smaller the better...

# %%
import gzip
import numpy as np

datapath = "../sdata"
infile = "smallstring.gz"

with gzip.open("%s/%s" % (datapath, infile), 'rb') as f:
    content = f.read()

testbytes = [b.encode('hex') for b in content]
n_bytes = len(testbytes)

# %%
modelfile = "../models/model_from_big_domain_string_1.gz_arch_8_32_32_unroll_20_step_3_dropout_0.1_iter_25.npy"
   
model_wts = np.load(modelfile)

arch = [model_wts[i].shape[0]\
       for i in range(len(model_wts))\
       if len(model_wts[i].shape) == 2] 

INSIZE = arch[0]
nh = len(arch)/2
nhidden = [arch[1+2*i] for i in range(nh)]
OUTSIZE = 256

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import LSTM, Recurrent

model = Sequential()
if nlayers > 1:
    for i in range(nlayers-1):
        model.add(LSTM(nhidden[i],
                       return_sequences=True,
                       input_shape=(unroll, INSIZE)))
    model.add(LSTM(nhidden[nlayers-1],
                   return_sequences=False))
else:
    model.add(LSTM(nhidden[0],
                   return_sequences=False,
                   input_shape=(unroll, INSIZE)))
model.add(Dense(OUTSIZE))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# load current weights
model.set_weights(model_wts)

# %%
import math

def bn(x):
    """
    Binary representation of 0-255 as 8-long int vector.
    """
    str = bin(x)[2:]
    while len(str) < 8:
        str = '0' + str
    return [int(i) for i in list(str)]

def entropy(pred):
    """
    Entropy of a soft-max vector.
    """
    return sum([-p*math.log(p) for p in pred if p > 0])

binabet = [bn(x) for x in range(256)]
byte_idx = dict((c, i) for i,c in enumerate(hexabet))
nlayers = len(nhidden)

# %%
unroll = 20
x = np.zeros((1, unroll, INSIZE))

def stepping(window):
    if INSIZE == 8:
        for t,b in enumerate(window):
            x[0, t, :] = binabet[byte_idx[b]]
    elif INSIZE == 256:
        for t,b in enumerate(window):
            x[0, t, byte_idx[b]] = 1.0
    return model.predict(x, verbose=0)[0]

window = testbytes[:unroll]
idx = unroll

entropies = []
while idx < n_bytes - unroll:
    preds = stepping(window)
    entropies += [entropy(preds)]
    next_byte = testbytes[idx]
    window = window[1:] + [next_byte]
    idx += 1

print(sum(entropies)/len(entropies))
# Out:
# 2.31826967235

# %% [markdown]
# testmodel: 4.94551499849
#
# big_string 10Ms on Macbook [INSIZE=256 ~60 iters]: 1.19513989953
#
# big_domain_string on GPU [INSIZE=8 arch 16]:
#
#
# | Iteration        | Entropy           |
# | ------------- |:-------------:|
# | 1     | 2.78878392504 |
# | 7      | 2.76468260125    |
# | 17 | 2.76468260125     |
# |30| 2.76859589659 |
#
# big_domain_string on GPU [INSIZE=8 arch 32,32]:
#
# | Iteration        | Entropy           |
# | ------------- |:-------------:|
# | 5     | 2.3545572814 |
# | 10      | 2.3470987331     |
# | 15 | 2.3276004177      |
# |20 | 2.3032590387 |
# | 25 | 2.3182696723 |
# | 30 | 2.3182696723 |
# | 35 | |
