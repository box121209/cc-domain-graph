# %% [markdown]
# # RNN model of URIs

# %% [markdown]
# The Python code from this notebook has now been developed into two scripts
# <ol>
# <li> <tt>train_rnn.py</tt>
# <code>
# Usage: python  ./python/train_rnn.py infile [options]
# Options are:
#         -o outfile
#         -datapath [./sdata]
#         -modelpath [./models]
#         -unroll [20]
#         -step [3]
#         -dropout [0.1]
#         -niters [10]
#         -arch (hidden layer sizes) [16]
# </code>
# <li> <tt>make_synthetic.py</tt>
# <code>
# Usage: python  ./python/make_synthetic.py infile [options]
# Options are:
#         -n length of output [1000]
#         -init        [newlines]
#         -temp        [1.0]
#         -modelpath        [./models]
# </ol>

# %% [markdown]
# ## Training a model

# %%
run -i train_rnn\
    smallstring.gz\
    -datapath ../sdata\
    -modelpath ../models\
    -arch 32,32\
    -niters 16
# Out:
# Checking hardware ...
# [name: "/cpu:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11201530596252466535
# ]
# Model architecture:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 20, 32)            5248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 20, 32)            0
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 32)                8320
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               8448
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# =================================================================
# Total params: 22,016
# Trainable params: 22,016
# Non-trainable params: 0
# _________________________________________________________________
# None
# Can't find existing model, initialising random weights
# Reading data file ../sdata/smallstring.gz ...
# Read 10000 bytes in 0.013794 seconds
# Cutting into byte sequences of size 20 ...
# Written 3327 sequences in 0.005031 seconds
# Formatting arrays ...
# Arrays written in 0.072629 seconds
# Fitting model ...
# Epoch block 0:
# Epoch 1/5
# 3327/3327 [==============================] - 5s - loss: 4.8256
# Epoch 2/5
# 3327/3327 [==============================] - 3s - loss: 3.8918
# Epoch 3/5
# 3327/3327 [==============================] - 5s - loss: 3.6957
# Epoch 4/5
# 3327/3327 [==============================] - 4s - loss: 3.6272
# Epoch 5/5
# 3327/3327 [==============================] - 4s - loss: 3.6063
# Epoch block 1:
# Epoch 1/5
# 3327/3327 [==============================] - 3s - loss: 3.5891
# Epoch 2/5
# 3327/3327 [==============================] - 3s - loss: 3.5783
# Epoch 3/5
# 3327/3327 [==============================] - 3s - loss: 3.5687
# Epoch 4/5
# 3327/3327 [==============================] - 3s - loss: 3.5576
# Epoch 5/5
# 3327/3327 [==============================] - 3s - loss: 3.5484
# Epoch block 2:
# Epoch 1/5
# 3327/3327 [==============================] - 3s - loss: 3.5418
# Epoch 2/5
# 3327/3327 [==============================] - 3s - loss: 3.5366
# Epoch 3/5
# 3327/3327 [==============================] - 3s - loss: 3.5269
# Epoch 4/5
# 3327/3327 [==============================] - 3s - loss: 3.5232
# Epoch 5/5
# 3327/3327 [==============================] - 3s - loss: 3.5180
# Epoch block 3:
# Epoch 1/1
# 3327/3327 [==============================] - 3s - loss: 3.5170
# Done in 119.908 seconds
# Model written to ../models/model_from_smallstring.gz_arch_8_32_32_unroll_20_step_3_dropout_0.1

# %% [markdown]
# ## Synthetic domain string from model

# %%
run -i make_synthetic\
    model_from_big_domain_string_1.gz_arch_8_32_32_unroll_20_step_3_dropout_0.1_iter_15.npy\
    -modelpath ../models\
    -init '叶问前传BD国语中字1024高清'\
    -temp 1.0\
    -n 4000
# Out:
# 叶问前传BD国语中字1024高清-//267-1-aCrlitem/runtiis
# /wels/3206/assary/
# /cams/hurnik-molustionum-kergek
# /-1793-2010-omt.htm
# /smarshotmosa
# /h000/lo-siarnedy-as-58-71158/
# /category/lam.asp
# /furda-withrokenhere.nap
# /eci/1
# /archiviteu/myocank-iralir.html
# /
#
#
#
# rigtlp.com
# /pcrcyhba8re2439147-Ajdedeate-15270/audionniuy.jpg
# /resast-lispitle
# /til/Image-ssshojeitions/guri-unshlitenchi-gsiga.jpg/-s/code/bipik1/vedijaeba/
# /dal9220-dimala-tir-332-%i1%b6%cd%a1%d3%8b%da%b7%d8%b1%d8%b1%db%83/%d8%a7%db%8c%d8%a7%d8%a7%d8%a8-%d8%a9%d8%aa%db%8c%d8%a8%d8%af.
# /dinast-namsdet4-7514-realco-pab-thonovaui-prej-ros.php
#
#
#
# taccmio/langrara-gloplud/page/tida-post.html
# /ecaspours/bout.jpg
# /13499-boct/images/no/
# /merus.html
# /caleche/dadokatires/c/260/c447-u-1.htm
# /av-iniFyser/
# /news/xost_suress/
# /Category/mestac
# /f3/530df21759242959fcd5a1cf5f42c-9379473-
# /product/115/948408
# /albailne/a/lert/17386/ast-cingfck/1704866.jpg
# /useluncamyner-reromay
# /anda/1543/erledhesss/
# /2014/02/toh468/
# /category/product/den/modloy/2016/04/pcsincide-powikl-in-seatic/
# /bartonemn_ingell/forl/scorama-natsinzoiny_P_2MP
# /beuin/3573/hodes-Lixeren-oc-bing-Smourdere94268248-4-jlprtex.jpg
# /sil/images/dobor/
# /stisionraks/18/t945-bigpe-net-
#
#
#
# www.mna.com
# /redunt/stoluger/306-spulsio/npajilic
# /auct6Me/sexve-waldeos_Dheyk-1257/b3001-segnulolos-reirin-wondkelb-39-alo-eclona-alkosror-gimblos/100101/mbdf/bani-ngren-gall-enni-307-b-galap-sasta-ocs--sygeten
# /blog/pakiy-13-foo-laono-ge-p.jpg
# /rqk/ems/ixpoidmocfigcrals/etlitunter/terwallanyt2.html
# /returtatero-Indmane_bropa.html
# /iant_sh
# /bcartej
# /mentile-as_fiiezhaomu.cot
# /no-w-e2000c78.html
# /naire/077-conhinia-orniriss
# /23120
# /47/fi-neget-fotuna-rendil-hams-fee-aca
# /innes.htm
# /jps/2018/05/forses/
# /cares
# /vodos/putC_unstatSBehlro_bnocatilytine-udhayis-ma-selze-bovengag/
# /feoo_ningb/jQu1cmjm720v11og4W0Tdl59obg_rzepdilma_mo.jpg
# /dhlaganaxmil/dolarnipviey/
# /filir.html
#
#
#
# 16.clibrelandar.go.wica
# /en/cuqkastop-shop/uferebor-2016/1131-ikkicom-omiazens.html
# /users/sennya-toaligs-the-fingh/
# /re0t51-taranciet/
# /poll/216737
# /wiky/
# /lier-Man-14%20Watouny_Sviley/or-T64983znlM-1081/
# /itom/-Parnpg.jpg
# /ids/cim/fastunt-siterie/mesers/bu/firl.html
# /Misleveis-Ufble-41-Ni.html
# /rozes/
# /812266/abud/-40/pruam_F/110307-13031.html
# /category/event.jpg
# /ubeidarests/shune-mpcllketress/
# /ap/demanikn.html
# /upload/vo-alemil-hoteen/2017-12-compa-new-nas--sincime-par
# /puen/
# /witment52.gif
# /iw9
# /spadol/article54R/vebice-lightir-kroeg/-201-.jpgf.tem-n0
# /yicdous/149310/carhors-opages
# /products/logo.html
# /category/tema-econy-paofuver-and-ligy/
# /8a0a-b2c2-025.html
# /category/mil-rindijel-hold.png
# /uwtu/pristx/uecation/120/2460/produitster_Nite.k%n4b0006eb5b978e3e7
# /sin-pir.html
# /meri/3/
# /index.php
# /zageinc-oblepre.jpg
# /ands/loofin.jpg
# /seocuding/d9a2db85d2_54855863992714/2-myxvofen/ll.ita.html
# /rubpluactireds-if-lomal-512/Des/2/1a4274934868366595862-othonuny/
# /category/dosrorielnites/
# /paslendis.html
# /catalog/bil/onlasming/grne1/channedazouogy-2015-03_3345.jpg
# /team/7.mise_higa..aoprope.cr
#
#
#
# ac.com
# /weitelanduzn/hoimminiGont/gyyey
# /avden/gallage/scetust-xaones-arits-ccymi-babil-omes-krinjus-de-amartun-ulepite-enii-1s-bady/boedau-2xenganri-rave-crosiganiery/-4-2018-Takfenii.html
# /faoma/H1-fans-
# /firpp-Hi-dinse
# /sindams/
# /5879532
#
#
#
# www.sillaB.nld/malstectetar/vim/pasts/A_SCVM5-BA05SMCBaC/ManoSC-Homeiga-Cart-lezeop-%c1%.jp/
# /bab
# /kifchis-a-de-2478827729-reksing-cR_12x4o6dbth.pames.jpg
# /2-1-enogerita
# /nie/trahhunt/
# /home/2/.galp/spost/efarizeratene.html
# /product/10685
# /archives/2815p/Images/Rhtich/5445.3b5
# /303x0201000001221
# /chotusd_allanzena-poll-conlecti684.htm
# /mes/Sabeunur/ganluha/image.html
# /bue/
#
#
#
# andpacestoyerime.aneule.com
# /2pr/481313/
# /2012-08/iblipetion/appers-EDT-D
# /CC
# /l3/3.html
#
#
#
# co-strar.com
# /delnoch
# /uhs/baen-clict
# /lerstafe-2187s7.gaf
# /tag/
# /phys/sens/inc-tremw-00/5s/3000002_0
# /wiri/17290_12979.jpg
# /product/imva/regarebidolly
# /images/nlivacy/phill-5_6u5.jpg
# /images/spacaterox/
# /schoung-pleafigitosl
# /sercts.html
# /lij/kinstitionms/images/pri63-6468.gif
# /k/748815--6-1-t-haifeatr-rekhats/
#
#
#
# zyh

# %% [markdown]
# ## Entropy of the model

# %% [markdown]
# How do we assess the performance of a model?
#
# Below I'm using code from <tt>make_synthetic.py</tt> to compute the average prediction entropy on a test string of 10k bytes.
#
# The smaller the better...

# %%
import gzip
import numpy as np

datapath = "../sdata"
infile = "smallstring.gz"

with gzip.open("%s/%s" % (datapath, infile), 'rb') as f:
    content = f.read()

testbytes = [b.encode('hex') for b in content]
n_bytes = len(testbytes)

# %%
modelfile = "../models/model_from_big_domain_string_1.gz_arch_8_32_32_unroll_20_step_3_dropout_0.1_iter_15.npy"
   
model_wts = np.load(modelfile)

arch = [model_wts[i].shape[0]\
       for i in range(len(model_wts))\
       if len(model_wts[i].shape) == 2] 

INSIZE = arch[0]
nh = len(arch)/2
nhidden = [arch[1+2*i] for i in range(nh)]
OUTSIZE = 256

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.layers.recurrent import LSTM, Recurrent

model = Sequential()
if nlayers > 1:
    for i in range(nlayers-1):
        model.add(LSTM(nhidden[i],
                       return_sequences=True,
                       input_shape=(unroll, INSIZE)))
    model.add(LSTM(nhidden[nlayers-1],
                   return_sequences=False))
else:
    model.add(LSTM(nhidden[0],
                   return_sequences=False,
                   input_shape=(unroll, INSIZE)))
model.add(Dense(OUTSIZE))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# load current weights
model.set_weights(model_wts)

# %%
import math

def bn(x):
    """
    Binary representation of 0-255 as 8-long int vector.
    """
    str = bin(x)[2:]
    while len(str) < 8:
        str = '0' + str
    return [int(i) for i in list(str)]

def entropy(pred):
    """
    Entropy of a soft-max vector.
    """
    return sum([-p*math.log(p) for p in pred if p > 0])

binabet = [bn(x) for x in range(256)]
byte_idx = dict((c, i) for i,c in enumerate(hexabet))
nlayers = len(nhidden)

# %%
unroll = 20
x = np.zeros((1, unroll, INSIZE))

def stepping(window):
    if INSIZE == 8:
        for t,b in enumerate(window):
            x[0, t, :] = binabet[byte_idx[b]]
    elif INSIZE == 256:
        for t,b in enumerate(window):
            x[0, t, byte_idx[b]] = 1.0
    return model.predict(x, verbose=0)[0]

window = testbytes[:unroll]
idx = unroll

entropies = []
while idx < n_bytes - unroll:
    preds = stepping(window)
    entropies += [entropy(preds)]
    next_byte = testbytes[idx]
    window = window[1:] + [next_byte]
    idx += 1

print(sum(entropies)/len(entropies))
# Out:
# 2.3276004177

# %% [markdown]
# testmodel: 4.94551499849
#
# big_string 10Ms on Macbook [INSIZE=256 ~60 iters]: 1.19513989953
#
# big_domain_string on GPU [INSIZE=8 arch 16]:
#
#
# | Iteration        | Entropy           |
# | ------------- |:-------------:|
# | 1     | 2.78878392504 |
# | 7      | 2.76468260125    |
# | 17 | 2.76468260125     |
# |30| 2.76859589659 |
#
# big_domain_string on GPU [INSIZE=8 arch 32,32]:
#
# | Iteration        | Entropy           |
# | ------------- |:-------------:|
# | 5     | 2.3545572814 |
# | 10      | 2.3470987331     |
# | 15 | 2.3276004177      |
# |20| |
